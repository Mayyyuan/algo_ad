# %%
user=pd.read_csv("../data/user_data")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7929566cebc1> in <module>()
# ----> 1 user=pd.read_csv("../data/user_data")
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
user=pd.read_csv("../data/user_data")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-3-7929566cebc1> in <module>()
# ----> 1 user=pd.read_csv("../data/user_data")
#
# D:\m_anaconda3.5.0\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
# ...

# %%
user=pd.read_csv("../data/user_data",error_bad_lines=False)
# Out:
# b'Skipping line 3: expected 519 fields, saw 943\nSkipping line 4: expected 519 fields, saw 647\nSkipping line 11: expected 519 fields, saw 648\nSkipping line 12: expected 519 fields, saw 560\nSkipping line 13: expected 519 fields, saw 788\nSkipping line 14: expected 519 fields, saw 529\nSkipping line 15: expected 519 fields, saw 572\nSkipping line 19: expected 519 fields, saw 986\nSkipping line 20: expected 519 fields, saw 552\nSkipping line 21: expected 519 fields, saw 1290\nSkipping line 23: expected 519 fields, saw 550\nSkipping line 24: expected 519 fields, saw 643\nSkipping line 29: expected 519 fields, saw 789\nSkipping line 31: expected 519 fields, saw 523\nSkipping line 37: expected 519 fields, saw 605\nSkipping line 39: expected 519 fields, saw 602\nSkipping line 43: expected 519 fields, saw 589\nSkipping line 45: expected 519 fields, saw 680\nSkipping line 46: expected 519 fields, saw 557\nSkipping line 47: expected 519 fields, saw 748\nSkipping line 58: expected 519 fields
# ...

# %%
user.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
user=pd.read_table("../data/user_data")

# %%
user.head()
# Out:
#     624218  753  2  \
# 0   271475  601  3
# 1    44439  819  3
# 2   863717    1  2
# 3  1305469  714  3
# 4   690515  731  2
#
#   523,7589,12527,9019,14605,13489,302,6222,14214,9706,6643,1053,2360,3955,1231,8243,-1  \
# 0  9019,9032,663,12527,14532,2416,2599,1987,9687,...
# 1  12527,14188,9841,9019,14605,6222,9962,6643,172...
# 2  12527,3435,2398,11069,1292,9019,14605,14348,62...
# 3  8928,9019,1540,719,12527,6051,10545,12118,7107...
# 4  12610,12527,8057,3228,9019,14605,6222,5779,954...
#
#     0  6  1  2.1 0.1  4  \
# 0  13  7  2    2   0  2
# 1  13  7  3    2   4  4
# 2   6  5  3    2   0  2
# 3  13  5  3    2   0  2
# 4  13  2  2    2   2  4
#
# ...

# %%
user=pd.read_table("../data/user_data",header=None)

# %%
user.head()
# Out:
#         0    1   2                                                  3   4   \
# 0   624218  753   2  523,7589,12527,9019,14605,13489,302,6222,14214...   0
# 1   271475  601   3  9019,9032,663,12527,14532,2416,2599,1987,9687,...  13
# 2    44439  819   3  12527,14188,9841,9019,14605,6222,9962,6643,172...  13
# 3   863717    1   2  12527,3435,2398,11069,1292,9019,14605,14348,62...   6
# 4  1305469  714   3  8928,9019,1540,719,12527,6051,10545,12118,7107...  13
#
#    5   6   7  8   9                                                  10
# 0   6   1   2  0   4  32612,34406,3413,33059,4275,4667,4561,34051,42...
# 1   7   2   2  0   2  4990,4992,3413,33061,4115,4876,2393,34167,3441...
# 2   7   3   2  4   4  3099,4403,34414,431,34415,5108,31686,3240,3229...
# 3   5   3   2  0   2  34293,845,3413,3099,33061,33059,4120,4410,4415...
# 4   5   3   2  0   2  32612,34289,34406,3413,4275,4410,4561,34051,34...

# %%
user=pd.read_table("../data/user_data",header=None,names=["UserId","Age","Gender","Area","Status","Education","Cons","Device","Work","Connect","Behavior"])

# %%
user.head()
# Out:
#     UserId  Age  Gender                                               Area  \
# 0   624218  753       2  523,7589,12527,9019,14605,13489,302,6222,14214...
# 1   271475  601       3  9019,9032,663,12527,14532,2416,2599,1987,9687,...
# 2    44439  819       3  12527,14188,9841,9019,14605,6222,9962,6643,172...
# 3   863717    1       2  12527,3435,2398,11069,1292,9019,14605,14348,62...
# 4  1305469  714       3  8928,9019,1540,719,12527,6051,10545,12118,7107...
#
#   Status  Education  Cons  Device Work  Connect  \
# 0      0          6     1       2    0        4
# 1     13          7     2       2    0        2
# 2     13          7     3       2    4        4
# 3      6          5     3       2    0        2
# 4     13          5     3       2    0        2
#
#                                             Behavior
# 0  32612,34406,3413,33059,4275,4667,4561,34051,42...
# 1  4990,4992,3413,33061,4115,4876,2393,34167,3441...
# 2  3099,4403,34414,431,34415,5108,31686,3240,3229...
# ...

# %%
log_0216=pd.read_csv("../data/2019-02-16.csv",header=None,names=["ReqId","ReqTime","ALid","UserId","Aid","Size","Bid","Pctr","Ecpm","TEcpm","Date"])
log_0216.head()
# Out:
#                                                ReqId  ReqTime  ALid  UserId  \
# 0  84053223\t1550332665\t240\t917194\t186369\t30\...      NaN   NaN     NaN
# 1  23482062\t1550332515\t39\t385699\t137171\t44\t...      NaN   NaN     NaN
# 2  34020708\t1550332384\t30\t613627\t185128\t64\t...      NaN   NaN     NaN
# 3  54435556\t1550332542\t196\t1290252\t293117\t44...      NaN   NaN     NaN
# 4  9415438\t1550330748\t58\t88563\t711505\t30\t11...      NaN   NaN     NaN
#
#    Aid  Size  Bid  Pctr  Ecpm  TEcpm  Date
# 0  NaN   NaN  NaN   NaN   NaN    NaN   NaN
# 1  NaN   NaN  NaN   NaN   NaN    NaN   NaN
# 2  NaN   NaN  NaN   NaN   NaN    NaN   NaN
# 3  NaN   NaN  NaN   NaN   NaN    NaN   NaN
# 4  NaN   NaN  NaN   NaN   NaN    NaN   NaN

# %%
log_0216=pd.read_table("../data/2019-02-16.csv",header=None,names=["ReqId","ReqTime","ALid","UserId","Aid","Size","Bid","Pctr","Ecpm","TEcpm","Date"])
log_0216.head()
# Out:
#       ReqId     ReqTime  ALid   UserId     Aid  Size  Bid    Pctr     Ecpm  \
# 0  84053223  1550332665   240   917194  186369    30   24   3.719    74.38
# 1  23482062  1550332515    39   385699  137171    44  312  17.932   358.64
# 2  34020708  1550332384    30   613627  185128    64   22  27.057   541.14
# 3  54435556  1550332542   196  1290252  293117    44  105  12.954   259.08
# 4   9415438  1550330748    58    88563  711505    30   11  68.282  1365.64
#
#       TEcpm        Date
# 0   163.636  2019-02-16
# 1  5952.640  2019-02-16
# 2  1136.394  2019-02-16
# 3  1619.080  2019-02-16
# 4  2116.742  2019-02-16

# %%
user_gender=user.groupby(['Gender'])['Gender'].value_counts()
user_gender
# Out:
# Gender  Gender
# 1       1          22961
# 2       2         281766
# 3       3         350036
# Name: Gender, dtype: int64

# %%
int count=0
for uid in log_0216['UserId']:
    if user['Gender'][user['UserId']==uid]==2:
        count++
# Out:
#   File "<ipython-input-15-f69ae390040d>", line 1
#     int count=0
#             ^
# SyntaxError: invalid syntax

# %%
count=0
i=0
for uid in log_0216['UserId']:
    print(count,":",user['Gender'][user['UserId']==uid]==2)
    if user['Gender'][user['UserId']==uid].any()==2:
        count+=1
    i+=1
count

# %%
count=0
for uid in log_0216['UserId']:
    if user['Gender'][user['UserId']==uid].any()=='2':
        count+=1

# %%
count
# Out:
# 0

# %%
countout=0
countin=0
for uid in log_0216['UserId']:
    if uid not in user['UserId']:
        countout+=1
    else:
        countin+=1
print("可以找到的：",countin)
print("不可以找到的:",countout)
# Out:
# 可以找到的： 4321
# 不可以找到的: 4857
